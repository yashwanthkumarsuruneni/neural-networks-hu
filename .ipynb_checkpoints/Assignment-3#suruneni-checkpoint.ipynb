# %% [markdown]
# ### Epoch - 25 , Hidden layer nodes - 50

# %% [markdown]
# The Questions of the assignment are explained after this, as we are using the model designed in the class

# %%
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# plot 4 images as gray scale
plt.subplot(221)
plt.imshow(X_train[0], cmap=plt.get_cmap('gray'))
plt.subplot(222)
plt.imshow(X_train[1], cmap=plt.get_cmap('gray'))
plt.subplot(223)
plt.imshow(X_train[2], cmap=plt.get_cmap('gray'))
plt.subplot(224)
plt.imshow(X_train[3], cmap=plt.get_cmap('gray'))
# show the plot
plt.show()
# Out:
# ...
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
num_pixels = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], num_pixels)
X_test = X_test.reshape(X_test.shape[0], num_pixels)

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
Y_test = y_test 
from keras.utils import np_utils
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]    #10 classes

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
#from tensorflow.keras import optimizers
hidden_layer_nodes=50
def baseline_model():
    # create model
    model = Sequential()
    model.add(Dense(hidden_layer_nodes, input_dim=num_pixels, activation='sigmoid'))
    model.add(Dense(hidden_layer_nodes, activation='sigmoid'))
    model.add(Dense(num_classes, activation='sigmoid'))
    #sgd = optimizers.SGD(lr=0.01, momentum=0.0, decay=0.0)
    # Compile model
    #model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
    return model

# %%
model = baseline_model()
# Fit the model
nn_simple = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=200)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=2)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/25
# 300/300 [==============================] - 1s 5ms/step - loss: 0.2101 - accuracy: 0.1070 - val_loss: 0.1513 - val_accuracy: 0.1101
# Epoch 2/25
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1285 - accuracy: 0.1143 - val_loss: 0.1134 - val_accuracy: 0.1304
# Epoch 3/25
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1065 - accuracy: 0.1288 - val_loss: 0.1013 - val_accuracy: 0.1413
# Epoch 4/25
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0986 - accuracy: 0.1372 - val_loss: 0.0963 - val_accuracy: 0.1443
# Epoch 5/25
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0950 - accuracy: 0.1411 - val_loss: 0.0938 - val_accuracy: 0.1427
# Epoch 6/25
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0931 - accuracy: 0.1387 - val_loss: 0.0924 - val_accuracy: 0.1406
# Epoch 7/25
# ...

# %% [markdown]
# ## Model Evaluation

# %%
plt.subplot(2,1,1)
plt.plot(nn_simple.history['accuracy'])
plt.plot(nn_simple.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(nn_simple.history['loss'])
plt.plot(nn_simple.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.show()

# %%
predicted_classes = model.predict_classes(X_test)
# see which we predicted correctly and which not
correct_indices = np.nonzero(predicted_classes == Y_test)[0]
incorrect_indices = np.nonzero(predicted_classes != Y_test)[0]
print()
print(len(correct_indices),"classified correctly")
print(len(incorrect_indices),"classified incorrectly")
# adapt figure size to accomodate 18 subplots
plt.rcParams['figure.figsize'] = (7,14)
figure_evaluation = plt.figure()
# plot 9 correct predictions
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(6,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title(
      "Predicted: {}, Truth: {}".format(predicted_classes[correct],
                                        Y_test[correct]))
    plt.xticks([])
    plt.yticks([])
# Out:
# WARNING:tensorflow:From <ipython-input-9-5c95e84225fd>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#
# 1200 classified correctly
# 8800 classified incorrectly

# %%
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(6,3,i+10)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title(
      "Predicted {}, Truth: {}".format(predicted_classes[incorrect], 
                                       Y_test[incorrect]))
    plt.xticks([])
    plt.yticks([])

figure_evaluation

# %% [markdown]
# ## Question: 1- Change the number of neurons in hidden layers to 65. See the accuracy and compared it to the baseline.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
#from tensorflow.keras import optimizers
hidden_layer_nodes=65
def baseline_model():
    # create model
    model = Sequential()
    model.add(Dense(hidden_layer_nodes, input_dim=num_pixels, activation='sigmoid'))
    model.add(Dense(hidden_layer_nodes, activation='sigmoid'))
    model.add(Dense(num_classes, activation='sigmoid'))
    #sgd = optimizers.SGD(lr=0.01, momentum=0.0, decay=0.0)
    # Compile model
    #model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
    return model

# %%
model = baseline_model()
# Fit the model
nn_simple = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=200)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=2)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/25
# 300/300 [==============================] - 1s 5ms/step - loss: 0.1727 - accuracy: 0.0976 - val_loss: 0.1277 - val_accuracy: 0.0980
# Epoch 2/25
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1130 - accuracy: 0.1187 - val_loss: 0.1036 - val_accuracy: 0.1422
# Epoch 3/25
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0995 - accuracy: 0.1596 - val_loss: 0.0964 - val_accuracy: 0.1680
# Epoch 4/25
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0947 - accuracy: 0.1741 - val_loss: 0.0934 - val_accuracy: 0.1688
# Epoch 5/25
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0926 - accuracy: 0.1766 - val_loss: 0.0920 - val_accuracy: 0.1847
# Epoch 6/25
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0915 - accuracy: 0.2051 - val_loss: 0.0911 - val_accuracy: 0.2182
# Epoch 7/25
# ...

# %% [markdown]
# The Baseline Error is 84.27% , And the Accuracy is 15.73% , when the number of neurons are 65.

# %% [markdown]
# ## Question: 2 - Change the number of epochs to 30 and see if it has any effect (50 neurons)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
#from tensorflow.keras import optimizers
hidden_layer_nodes=50
def baseline_model():
    # create model
    model = Sequential()
    model.add(Dense(hidden_layer_nodes, input_dim=num_pixels, activation='sigmoid'))
    model.add(Dense(hidden_layer_nodes, activation='sigmoid'))
    model.add(Dense(num_classes, activation='sigmoid'))
    #sgd = optimizers.SGD(lr=0.01, momentum=0.0, decay=0.0)
    # Compile model
    #model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
    return model

# %%
model = baseline_model()
# Fit the model
nn_simple = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=30, batch_size=200)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=2)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/30
# 300/300 [==============================] - 1s 5ms/step - loss: 0.1681 - accuracy: 0.1007 - val_loss: 0.1332 - val_accuracy: 0.0868
# Epoch 2/30
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1188 - accuracy: 0.0869 - val_loss: 0.1086 - val_accuracy: 0.0907
# Epoch 3/30
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1036 - accuracy: 0.0912 - val_loss: 0.0998 - val_accuracy: 0.0977
# Epoch 4/30
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0975 - accuracy: 0.0957 - val_loss: 0.0957 - val_accuracy: 0.1023
# Epoch 5/30
# 300/300 [==============================] - 1s 4ms/step - loss: 0.0946 - accuracy: 0.0993 - val_loss: 0.0936 - val_accuracy: 0.1068
# Epoch 6/30
# 300/300 [==============================] - 1s 5ms/step - loss: 0.0929 - accuracy: 0.1081 - val_loss: 0.0923 - val_accuracy: 0.1253
# Epoch 7/30
# ...

# %% [markdown]
# The accuracy has went down from 12.00% to 11.60% with 30 epochs

# %% [markdown]
# ## Question-3: Add one more layer to the designed neural network and see the result (This layer contains 20 nodes). Draw graphs and compare accuracies.

# %%
# Adding one more layer to the layer of 50 hidden neurons
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
#from tensorflow.keras import optimizers
hidden_layer_nodes=50
# The new layer has 20 neurons
new_layer_nodes=20
def baseline_model():
    # create model
    model = Sequential()
    model.add(Dense(hidden_layer_nodes, input_dim=num_pixels, activation='sigmoid'))
    model.add(Dense(hidden_layer_nodes, activation='sigmoid'))
    model.add(Dense(new_layer_nodes, activation='sigmoid'))
    model.add(Dense(num_classes, activation='sigmoid'))
    #sgd = optimizers.SGD(lr=0.01, momentum=0.0, decay=0.0)
    # Compile model
    #model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
    return model

# %%
model = baseline_model()
# Fit the model
nn_simple = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=30, batch_size=200)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=2)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/30
# 300/300 [==============================] - 1s 5ms/step - loss: 0.2217 - accuracy: 0.0974 - val_loss: 0.1903 - val_accuracy: 0.0982
# Epoch 2/30
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1682 - accuracy: 0.0974 - val_loss: 0.1498 - val_accuracy: 0.0982
# Epoch 3/30
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1374 - accuracy: 0.0974 - val_loss: 0.1271 - val_accuracy: 0.0982
# Epoch 4/30
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1202 - accuracy: 0.0974 - val_loss: 0.1143 - val_accuracy: 0.0982
# Epoch 5/30
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1103 - accuracy: 0.0974 - val_loss: 0.1067 - val_accuracy: 0.0982
# Epoch 6/30
# 300/300 [==============================] - 1s 4ms/step - loss: 0.1042 - accuracy: 0.0974 - val_loss: 0.1020 - val_accuracy: 0.0982
# Epoch 7/30
# ...

# %%
plt.subplot(2,1,1)
plt.plot(nn_simple.history['accuracy'])
plt.plot(nn_simple.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(nn_simple.history['loss'])
plt.plot(nn_simple.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.show()

# %%
predicted_classes = model.predict_classes(X_test)
# see which we predicted correctly and which not
correct_indices = np.nonzero(predicted_classes == Y_test)[0]
incorrect_indices = np.nonzero(predicted_classes != Y_test)[0]
print()
print(len(correct_indices),"classified correctly")
print(len(incorrect_indices),"classified incorrectly")
# adapt figure size to accomodate 18 subplots
plt.rcParams['figure.figsize'] = (7,14)
figure_evaluation = plt.figure()
# plot 9 correct predictions
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(6,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title(
      "Predicted: {}, Truth: {}".format(predicted_classes[correct],
                                        Y_test[correct]))
    plt.xticks([])
    plt.yticks([])
# Out:
# 1135 classified correctly
# 8865 classified incorrectly

# %%
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(6,3,i+10)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title(
      "Predicted {}, Truth: {}".format(predicted_classes[incorrect], 
                                       Y_test[incorrect]))
    plt.xticks([])
    plt.yticks([])

figure_evaluation

# %% [markdown]
# The accuracy is around 11.35% when we add an extra layer with 20 nodes.
